# %%
# Install tmdbsimple (only need to run once)
# !pip install tmdbsimple
# Out:
# Requirement already satisfied: tmdbsimple in /Users/milkasantana/anaconda3/envs/dojo-env/lib/python3.9/site-packages (2.9.1)
# Requirement already satisfied: requests in /Users/milkasantana/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from tmdbsimple) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/milkasantana/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->tmdbsimple) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /Users/milkasantana/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->tmdbsimple) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/milkasantana/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->tmdbsimple) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/milkasantana/anaconda3/envs/dojo-env/lib/python3.9/site-packages (from requests->tmdbsimple) (2022.9.24)

# %%
import json
with open('/Users/milkasantana/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']

# %%
## make a movie object using the .Movies function from tmdb
movie = tmdb.Movies(603)
movie

# %%
## movie objects have a .info dictionary 
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/oMsxZEvz9a708d49b6UdZK1KAo5.jpg',
#  'belongs_to_collection': {'id': 2344,
#   'name': 'The Matrix Collection',
#   'poster_path': '/bV9qTVHTVf0gkW0j7p7M0ILD4pG.jpg',
#   'backdrop_path': '/bRm2DEgUiYciDw3myHuYFInD7la.jpg'},
#  'budget': 63000000,
#  'genres': [{'id': 28, 'name': 'Action'},
#   {'id': 878, 'name': 'Science Fiction'}],
#  'homepage': 'http://www.warnerbros.com/matrix',
#  'id': 603,
#  'imdb_id': 'tt0133093',
#  'original_language': 'en',
#  'original_title': 'The Matrix',
#  'overview': 'Set in the 22nd century, The Matrix tells the story of a computer hacker who joins a group of underground insurgents fighting the vast and powerful computers who now rule the earth.',
#  'popularity': 68.694,
#  'poster_path': '/f89U3ADr1oiB1s9GkdPOEpXUk5H.jpg',
#  'production_companies': [{'id': 79,
#    'logo_path': '/tpFpsqbleCzEE2p5EgvUq6ozfCA.png',
#    'name': 'Village Roadshow Pictures',
#    'origin_country': 'US'},
#   {'id': 372,
#    'logo_path': None,
#    'name': 'Groucho II Film Partnership',
#    'origin_country': ''},
#   {'id': 1885,
#    'logo_path': '/xlvoOZr4s1PygosrwZyolIFe5xs.png',
#    'name': 'Silver Pictures',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1999-03-30',
#  'revenue': 463517383,
#  'runtime': 136,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Welcome to the Real World.',
#  'title': 'The Matrix',
#  'video': False,
#  'vote_average': 8.205,
#  'vote_count': 23546}

# %%
info['budget']
# Out:
# 63000000

# %%
info['revenue']
# Out:
# 463517383

# %%
info['imdb_id']
# Out:
# 'tt0133093'

# %%
movie = tmdb.Movies('tt1361336')
info = movie.info()
info['budget']
# Out:
# 50000000

# %%
response =movie.releases()

# %%
response
# Out:
# {'id': 587807,
#  'countries': [{'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CO',
#    'primary': False,
#    'release_date': '2021-02-12'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2021-02-26'},
#   {'certification': 'ALL',
#    'descriptors': [],
#    'iso_3166_1': 'KR',
#    'primary': False,
#    'release_date': '2021-02-24'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'ID',
#    'primary': False,
#    'release_date': '2021-03-10'},
#   {'certification': '6',
#    'descriptors': [],
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2021-06-09'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'IE',
#    'primary': False,
#    'release_date': '2021-05-07'},
#   {'certification': 'M/6',
#    'descriptors': [],
#    'iso_3166_1': 'PT',
#    'primary': False,
#    'release_date': '2021-03-04'},
#   {'certification': '6+',
#    'descriptors': [],
#    'iso_3166_1': 'RU',
#    'primary': False,
#    'release_date': '2021-02-25'},
#   {'certification': 'L',
#    'descriptors': [],
#    'iso_3166_1': 'BR',
#    'primary': False,
#    'release_date': '2021-02-11'},
#   {'certification': '7',
#    'descriptors': [],
#    'iso_3166_1': 'DK',
#    'primary': False,
#    'release_date': '2021-02-11'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '2021-04-01'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'HK',
#    'primary': False,
#    'release_date': '2021-03-11'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2021-05-19'},
#   {'certification': 'Btl',
#    'descriptors': [],
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '2021-05-28'},
#   {'certification': '0',
#    'descriptors': [],
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '2021-06-17'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CZ',
#    'primary': False,
#    'release_date': '2021-06-10'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'SK',
#    'primary': False,
#    'release_date': '2021-05-27'},
#   {'certification': 'V',
#    'descriptors': [],
#    'iso_3166_1': 'LT',
#    'primary': False,
#    'release_date': '2021-05-07'},
#   {'certification': '6',
#    'descriptors': [],
#    'iso_3166_1': 'HU',
#    'primary': False,
#    'release_date': '2021-05-20'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'PL',
#    'primary': False,
#    'release_date': '2021-06-11'},
#   {'certification': '7',
#    'descriptors': [],
#    'iso_3166_1': 'ES',
#    'primary': False,
#    'release_date': '2021-03-26'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '2021-02-11'},
#   {'certification': 'Κ',
#    'descriptors': [],
#    'iso_3166_1': 'GR',
#    'primary': False,
#    'release_date': '2021-06-10'},
#   {'certification': '普遍級',
#    'descriptors': [],
#    'iso_3166_1': 'TW',
#    'primary': False,
#    'release_date': '2021-02-10'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'KZ',
#    'primary': False,
#    'release_date': '2021-02-25'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2021-02-26'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '2021-03-25'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '2021-06-01'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'NZ',
#    'primary': False,
#    'release_date': '2021-06-01'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2021-09-16'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2022-02-16'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '2021-05-24'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '2021-06-21'},
#   {'certification': 'PG',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2021-05-18'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2021-09-22'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'GR',
#    'primary': False,
#    'release_date': '2021-09-23'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CA',
#    'primary': False,
#    'release_date': '2021-07-31'}]}

# %%
# example from package README
# source = https://github.com/celiao/tmdbsimple
releases = movie.releases()
for c in releases['countries']:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
# Out:
# PG
# PG
# PG

# %%
# Get the movie object for the current id
movie = tmdb.Movies('tt1361336')
# save the .info .releases dictionaries
info = movie.info()
releases = movie.releases()
# Loop through countries in releases
for c in releases['countries']:
    # if the country abbreviation==US
    if c['iso_3166_1' ] =='US':
        ## save a "certification" key in the info dict with the certification
       info['certification'] = c['certification']

# %%
def get_movie_with_rating(movie_id):
    movie = tmdb.Movies('tt1361336')
    info = movie.info()
    releases = movie.releases()
    for c in releases ['countries']:
        if c['iso_3166_1'] =='US':
            info['certification'] =c['certification']
    return info

# %%
info
# Out:
# {'adult': False,
#  'backdrop_path': '/9ns9463dwOeo1CK1JU2wirL5Yi1.jpg',
#  'belongs_to_collection': None,
#  'budget': 50000000,
#  'genres': [{'id': 35, 'name': 'Comedy'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 16, 'name': 'Animation'}],
#  'homepage': 'https://www.tomandjerrymovie.com',
#  'id': 587807,
#  'imdb_id': 'tt1361336',
#  'original_language': 'en',
#  'original_title': 'Tom & Jerry',
#  'overview': 'Tom the cat and Jerry the mouse get kicked out of their home and relocate to a fancy New York hotel, where a scrappy employee named Kayla will lose her job if she can’t evict Jerry before a high-class wedding at the hotel. Her solution? Hiring Tom to get rid of the pesky mouse.',
#  'popularity': 51.915,
#  'poster_path': '/8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg',
#  'production_companies': [{'id': 25120,
#    'logo_path': '/lMj6nMJBOzfLEd2fu8uF530AJcv.png',
#    'name': 'Warner Bros. Pictures Animation',
#    'origin_country': 'US'},
#   {'id': 8922,
#    'logo_path': '/yZWehAyjfKi4KvKeg1bkJ1bm5H8.png',
#    'name': 'Turner Entertainment',
#    'origin_country': 'US'},
#   {'id': 77061,
#    'logo_path': None,
#    'name': 'The Story Company',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2021-02-10',
#  'revenue': 136536687,
#  'runtime': 101,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Best of enemies. Worst of friends.',
#  'title': 'Tom & Jerry',
#  'video': False,
#  'vote_average': 6.876,
#  'vote_count': 2251,
#  'certification': 'PG'}

# %%
test = get_movie_with_rating('tt0848228') #put your function name here
test
# Out:
# {'adult': False,
#  'backdrop_path': '/9ns9463dwOeo1CK1JU2wirL5Yi1.jpg',
#  'belongs_to_collection': None,
#  'budget': 50000000,
#  'genres': [{'id': 35, 'name': 'Comedy'},
#   {'id': 10751, 'name': 'Family'},
#   {'id': 16, 'name': 'Animation'}],
#  'homepage': 'https://www.tomandjerrymovie.com',
#  'id': 587807,
#  'imdb_id': 'tt1361336',
#  'original_language': 'en',
#  'original_title': 'Tom & Jerry',
#  'overview': 'Tom the cat and Jerry the mouse get kicked out of their home and relocate to a fancy New York hotel, where a scrappy employee named Kayla will lose her job if she can’t evict Jerry before a high-class wedding at the hotel. Her solution? Hiring Tom to get rid of the pesky mouse.',
#  'popularity': 51.915,
#  'poster_path': '/8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg',
#  'production_companies': [{'id': 25120,
#    'logo_path': '/lMj6nMJBOzfLEd2fu8uF530AJcv.png',
#    'name': 'Warner Bros. Pictures Animation',
#    'origin_country': 'US'},
#   {'id': 8922,
#    'logo_path': '/yZWehAyjfKi4KvKeg1bkJ1bm5H8.png',
#    'name': 'Turner Entertainment',
#    'origin_country': 'US'},
#   {'id': 77061,
#    'logo_path': None,
#    'name': 'The Story Company',
#    'origin_country': 'US'},
#   {'id': 174,
#    'logo_path': '/IuAlhI9eVC9Z8UQWOIDdWRKSEJ.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '2021-02-10',
#  'revenue': 136536687,
#  'runtime': 101,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'Best of enemies. Worst of friends.',
#  'title': 'Tom & Jerry',
#  'video': False,
#  'vote_average': 6.876,
#  'vote_count': 2251,
#  'certification': 'PG'}

# %%
## testing our function by looping through a list of ids
import pandas as pd
test_ids = ["tt0848228", "tt0115937","tt0848228","tt0332280"]
results = []
for movie_id in test_ids:
    movie_info = get_movie_with_rating(movie_id)
    results.append(movie_info)
    
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path belongs_to_collection    budget  \
# 0  False  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                  None  50000000
# 1  False  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                  None  50000000
# 2  False  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                  None  50000000
# 3  False  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                  None  50000000
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                            homepage      id    imdb_id original_language  \
# 0  https://www.tomandjerrymovie.com  587807  tt1361336                en
# 1  https://www.tomandjerrymovie.com  587807  tt1361336                en
# 2  https://www.tomandjerrymovie.com  587807  tt1361336                en
# 3  https://www.tomandjerrymovie.com  587807  tt1361336                en
#
#   original_title  ...    revenue  runtime  \
# 0    Tom & Jerry  ...  136536687      101
# 1    Tom & Jerry  ...  136536687      101
# 2    Tom & Jerry  ...  136536687      101
# 3    Tom & Jerry  ...  136536687      101
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                               tagline        title  video  vote_average  \
# 0  Best of enemies. Worst of friends.  Tom & Jerry  False         6.876
# 1  Best of enemies. Worst of friends.  Tom & Jerry  False         6.876
# 2  Best of enemies. Worst of friends.  Tom & Jerry  False         6.876
# 3  Best of enemies. Worst of friends.  Tom & Jerry  False         6.876
#
#   vote_count certification
# 0       2251            PG
# 1       2251            PG
# 2       2251            PG
# 3       2251            PG
#
# [4 rows x 26 columns]

# %% [markdown]
# ## PART II : LOOP IN PARTS

# %%
import os, time,json
import tmdbsimple as tmdb 
from tqdm.notebook import tqdm_notebook
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['File Location.ipynb',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'file path.ipynb',
#  'tmdb_api_results_2001.json',
#  'title_basics.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  '.ipynb_checkpoints',
#  'title_akas.csv.gz',
#  'title_ratings.csv.gz']

# %%
YEARS_TO_GET = [2000,2001]

# %%
# Start of OUTER loop
#for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):

# %%
YEAR = 2000

# %%
#Defining the JSON file to store results for year
JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'

# %%
# Check if file exists
file_exists = os.path.isfile(JSON_FILE)

# %%
# If it does not exist: create it
if file_exists == False:
    # save an empty dict with just "imdb_id" to the new json file.
     with open(JSON_FILE,'w') as f:
        json.dump([{'imdb_id':0}],f)

# %%
import pandas as pd
# Load in the dataframe from project part 1 as basics:
basics = pd.read_csv("/Users/milkasantana/Documents/GitHub/IMDB_Project/Data/title_basics.csv.gz")
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0043139     movie                        Life of a Beijing Policeman
# 2  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1                           Wo zhe yi bei zi        0       2013      NaN
# 2  El tango del viudo y su espejo deformante        0       2020      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                          The Naked Monster        0       2005      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1             120           Drama,History
# 2              70                   Drama
# 3             122                   Drama
# 4             100    Comedy,Horror,Sci-Fi

# %%
#Saving new year as the current df
df = basics.loc[ basics['startYear']==YEAR].copy()

# %%
#saving movie ids to lit
movie_ids = df['tconst'].copy()#.to_list()
movie_ids
# Out:
# 9        tt0113026
# 10       tt0113092
# 12       tt0115937
# 13       tt0116391
# 14       tt0116628
#            ...
# 82026    tt8327752
# 82787    tt8553964
# 83907    tt8907070
# 84055    tt8954964
# 85539    tt9412476
# Name: tconst, Length: 1454, dtype: object

# %%
# Load existing data from json into a dataframe called "previous_df"
previous_df = pd.read_json(JSON_FILE)
previous_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...         ...    ...                               ...
# 1789  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1790  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1791  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1792  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1793  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN         NaN
# 1                       NaN  50000000.0
# 2                       NaN  50000000.0
# 3                       NaN  50000000.0
# 4                       NaN  50000000.0
# ...                     ...         ...
# 1789                    NaN  50000000.0
# 1790                    NaN  50000000.0
# 1791                    NaN  50000000.0
# 1792                    NaN  50000000.0
# 1793                    NaN  50000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...                                                 ...
# 1789  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1790  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1791  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1792  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1793  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1     https://www.tomandjerrymovie.com  587807.0                en
# 2     https://www.tomandjerrymovie.com  587807.0                en
# 3     https://www.tomandjerrymovie.com  587807.0                en
# 4     https://www.tomandjerrymovie.com  587807.0                en
# ...                                ...       ...               ...
# 1789  https://www.tomandjerrymovie.com  587807.0                en
# 1790  https://www.tomandjerrymovie.com  587807.0                en
# 1791  https://www.tomandjerrymovie.com  587807.0                en
# 1792  https://www.tomandjerrymovie.com  587807.0                en
# 1793  https://www.tomandjerrymovie.com  587807.0                en
#
#      original_title  ...      revenue  runtime  \
# 0               NaN  ...          NaN      NaN
# 1       Tom & Jerry  ...  136536687.0    101.0
# 2       Tom & Jerry  ...  136536687.0    101.0
# 3       Tom & Jerry  ...  136536687.0    101.0
# 4       Tom & Jerry  ...  136536687.0    101.0
# ...             ...  ...          ...      ...
# 1789    Tom & Jerry  ...  136536687.0    101.0
# 1790    Tom & Jerry  ...  136536687.0    101.0
# 1791    Tom & Jerry  ...  136536687.0    101.0
# 1792    Tom & Jerry  ...  136536687.0    101.0
# 1793    Tom & Jerry  ...  136536687.0    101.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 1789  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1790  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1791  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1792  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1793  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline        title  video  vote_average  \
# 0                                    NaN          NaN    NaN           NaN
# 1     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 2     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 3     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 4     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# ...                                  ...          ...    ...           ...
# 1789  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1790  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1791  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1792  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1793  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
#
#      vote_count certification
# 0           NaN           NaN
# 1        2243.0            PG
# 2        2243.0            PG
# 3        2243.0            PG
# 4        2243.0            PG
# ...         ...           ...
# 1789     2251.0            PG
# 1790     2251.0            PG
# 1791     2251.0            PG
# 1792     2251.0            PG
# 1793     2251.0            PG
#
# [1794 rows x 26 columns]

# %%
# filter out any ids that are already in the JSON_FILE
movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
#Get index and movie id from list
# INNER Loop
for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
    try:
        # Retrieve then data for the movie id
        temp = get_movie_with_rating(movie_id)  
        # Append/extend results to existing file using a pre-made function
        write_json(temp,JSON_FILE)
        # Short 20 ms sleep to prevent overwhelming server
        time.sleep(0.02)
            
    except Exception as e:
        errors.append([movie_id, e])
# Out:
# Movies from 2000:   0%|          | 0/1454 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [31], line 9
#       3 for movie_id in tqdm_notebook(movie_ids_to_get,
#       4                                   desc=f'Movies from {YEAR}',
#       5                                   position=1,
#       6                                   leave=True):
#       7     try:
#       8         # Retrieve then data for the movie id
# ----> 9         temp = get_movie_with_rating(movie_id)
#      10         # Append/extend results to existing file using a pre-made function
#      11         write_json(temp,JSON_FILE)
#
# Cell In [14], line 4, in get_movie_with_rating(movie_id)
#       2 movie = tmdb.Movies('tt1361336')
#       3 info = movie.info()
# ----> 4 releases = movie.releases()
#       5 for c in releases ['countries']:
#       6     if c['iso_3166_1'] =='US':
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/tmdbsimple/movies.py:528, in Movies.releases(self, **kwargs)
#     516 """
#     517 Get the release date and certification information by country for a
#     518 specific movie id.
#    (...)
#     524     A dict representation of the JSON returned from the API.
#     525 """
#     526 path = self._get_id_path('releases')
# --> 528 response = self._GET(path, kwargs)
#     529 self._set_attrs_to_values(response)
#     530 return response
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/tmdbsimple/base.py:110, in TMDB._GET(self, path, params)
#     109 def _GET(self, path, params=None):
# --> 110     return self._request('GET', path, params=params)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/tmdbsimple/base.py:87, in TMDB._request(self, method, path, params, payload)
#      85 # Create a new request session if no global session is defined
#      86 if self.session is None:
# ---> 87     response = requests.request(
#      88         method,
#      89         url,
#      90         params=params,
#      91         data=json.dumps(payload) if payload else payload,
#      92         headers=self.headers, timeout=self.timeout
#      93     )
#      95 # Use the global requests session the user provided
#      96 else:
#      97     response = self.session.request(
#      98         method,
#      99         url,
#    (...)
#     102         headers=self.headers, timeout=self.timeout
#     103     )
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038         if timeout == 0.0:
#    1039             # non-blocking
#    1040             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041         self.do_handshake()
#    1042 except (OSError, ValueError):
#    1043     self.close()
#
# File ~/anaconda3/envs/dojo-env/lib/python3.9/ssl.py:1310, in SSLSocket.do_handshake(self, block)
#    1308     if timeout == 0.0 and block:
#    1309         self.settimeout(None)
# -> 1310     self._sslobj.do_handshake()
#    1311 finally:
#    1312     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
final_year_df = pd.read_json(JSON_FILE)
final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)

# %% [markdown]
# ### COMBINING IN 1 LOOP

# %%
YEARS_TO_GET = [2000,2001]

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    
    # If it does not exist: create it
    if file_exists == False:
    # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)

    #Saving new year as the current df
    df = basics.loc[ basics['startYear']==YEAR].copy()

    #saving movie ids to lit
    movie_ids = df['tconst'].copy()#.to_list()
    movie_ids
    
    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)
    previous_df


    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

    #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            continue 



    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/1454 [00:00<?, ?it/s]
# Movies from 2001:   0%|          | 0/1573 [00:00<?, ?it/s]

# %%
YEAR = 2001

# %%
# Start of OUTER loop
for YEAR in tqdm_notebook(YEARS_TO_GET, desc='YEARS', position=0):
    #Defining the JSON file to store results for year
    JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'
    # Check if file exists
    file_exists = os.path.isfile(JSON_FILE)
    
    # If it does not exist: create it
    if file_exists == False:
    # save an empty dict with just "imdb_id" to the new json file.
        with open(JSON_FILE,'w') as f:
            json.dump([{'imdb_id':0}],f)

    #Saving new year as the current df
    df = basics.loc[ basics['startYear']==YEAR].copy()

    #saving movie ids to lit
    movie_ids = df['tconst'].copy()#.to_list()
    movie_ids
    
    # Load existing data from json into a dataframe called "previous_df"
    previous_df = pd.read_json(JSON_FILE)
    previous_df


    # filter out any ids that are already in the JSON_FILE
    movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

    #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm_notebook(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            continue 



    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)
# Out:
# YEARS:   0%|          | 0/2 [00:00<?, ?it/s]
# Movies from 2000:   0%|          | 0/1454 [00:00<?, ?it/s]
# Movies from 2001:   0%|          | 0/1573 [00:00<?, ?it/s]

# %% [markdown]
# ### PART III Exploratory Data Analysis

# %%
# Define the paths 
file_path_2000 = '/Users/milkasantana/Documents/GitHub/IMDB_Project/Data/final_tmdb_data_2000.csv.gz'

# Load the CSV files into separate DataFrames
df_2000 = pd.read_csv(file_path_2000, compression='gzip')
df_2000
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...         ...    ...                               ...
# 5260  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 5261  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 5262  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 5263  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 5264  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN         NaN
# 1                       NaN  50000000.0
# 2                       NaN  50000000.0
# 3                       NaN  50000000.0
# 4                       NaN  50000000.0
# ...                     ...         ...
# 5260                    NaN  50000000.0
# 5261                    NaN  50000000.0
# 5262                    NaN  50000000.0
# 5263                    NaN  50000000.0
# 5264                    NaN  50000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...                                                 ...
# 5260  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 5261  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 5262  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 5263  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 5264  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1     https://www.tomandjerrymovie.com  587807.0                en
# 2     https://www.tomandjerrymovie.com  587807.0                en
# 3     https://www.tomandjerrymovie.com  587807.0                en
# 4     https://www.tomandjerrymovie.com  587807.0                en
# ...                                ...       ...               ...
# 5260  https://www.tomandjerrymovie.com  587807.0                en
# 5261  https://www.tomandjerrymovie.com  587807.0                en
# 5262  https://www.tomandjerrymovie.com  587807.0                en
# 5263  https://www.tomandjerrymovie.com  587807.0                en
# 5264  https://www.tomandjerrymovie.com  587807.0                en
#
#      original_title  ...      revenue  runtime  \
# 0               NaN  ...          NaN      NaN
# 1       Tom & Jerry  ...  136536687.0    101.0
# 2       Tom & Jerry  ...  136536687.0    101.0
# 3       Tom & Jerry  ...  136536687.0    101.0
# 4       Tom & Jerry  ...  136536687.0    101.0
# ...             ...  ...          ...      ...
# 5260    Tom & Jerry  ...  136536687.0    101.0
# 5261    Tom & Jerry  ...  136536687.0    101.0
# 5262    Tom & Jerry  ...  136536687.0    101.0
# 5263    Tom & Jerry  ...  136536687.0    101.0
# 5264    Tom & Jerry  ...  136536687.0    101.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 5260  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5261  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5262  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5263  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5264  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline        title  video  vote_average  \
# 0                                    NaN          NaN    NaN           NaN
# 1     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 2     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 3     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 4     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# ...                                  ...          ...    ...           ...
# 5260  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 5261  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 5262  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 5263  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 5264  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
#
#      vote_count certification
# 0           NaN           NaN
# 1        2243.0            PG
# 2        2243.0            PG
# 3        2243.0            PG
# 4        2243.0            PG
# ...         ...           ...
# 5260     2251.0            PG
# 5261     2251.0            PG
# 5262     2251.0            PG
# 5263     2251.0            PG
# 5264     2251.0            PG
#
# [5265 rows x 26 columns]

# %%
# Define the paths 
file_path_2001 = '/Users/milkasantana/Documents/GitHub/IMDB_Project/Data/final_tmdb_data_2001.csv.gz'

# Load the CSV files into separate DataFrames
df_2001 = pd.read_csv(file_path_2001, compression='gzip')
df_2001
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...         ...    ...                               ...
# 1965  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1966  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1967  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1968  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 1969  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN         NaN
# 1                       NaN  50000000.0
# 2                       NaN  50000000.0
# 3                       NaN  50000000.0
# 4                       NaN  50000000.0
# ...                     ...         ...
# 1965                    NaN  50000000.0
# 1966                    NaN  50000000.0
# 1967                    NaN  50000000.0
# 1968                    NaN  50000000.0
# 1969                    NaN  50000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...                                                 ...
# 1965  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1966  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1967  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1968  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 1969  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1     https://www.tomandjerrymovie.com  587807.0                en
# 2     https://www.tomandjerrymovie.com  587807.0                en
# 3     https://www.tomandjerrymovie.com  587807.0                en
# 4     https://www.tomandjerrymovie.com  587807.0                en
# ...                                ...       ...               ...
# 1965  https://www.tomandjerrymovie.com  587807.0                en
# 1966  https://www.tomandjerrymovie.com  587807.0                en
# 1967  https://www.tomandjerrymovie.com  587807.0                en
# 1968  https://www.tomandjerrymovie.com  587807.0                en
# 1969  https://www.tomandjerrymovie.com  587807.0                en
#
#      original_title  ...      revenue  runtime  \
# 0               NaN  ...          NaN      NaN
# 1       Tom & Jerry  ...  136536687.0    101.0
# 2       Tom & Jerry  ...  136536687.0    101.0
# 3       Tom & Jerry  ...  136536687.0    101.0
# 4       Tom & Jerry  ...  136536687.0    101.0
# ...             ...  ...          ...      ...
# 1965    Tom & Jerry  ...  136536687.0    101.0
# 1966    Tom & Jerry  ...  136536687.0    101.0
# 1967    Tom & Jerry  ...  136536687.0    101.0
# 1968    Tom & Jerry  ...  136536687.0    101.0
# 1969    Tom & Jerry  ...  136536687.0    101.0
#
#                                        spoken_languages    status  \
# 0                                                   NaN       NaN
# 1     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4     [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...                                                 ...       ...
# 1965  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1966  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1967  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1968  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1969  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                  tagline        title  video  vote_average  \
# 0                                    NaN          NaN    NaN           NaN
# 1     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 2     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 3     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 4     Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# ...                                  ...          ...    ...           ...
# 1965  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1966  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1967  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1968  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
# 1969  Best of enemies. Worst of friends.  Tom & Jerry    0.0         6.876
#
#      vote_count certification
# 0           NaN           NaN
# 1        2251.0            PG
# 2        2251.0            PG
# 3        2251.0            PG
# 4        2251.0            PG
# ...         ...           ...
# 1965     2251.0            PG
# 1966     2251.0            PG
# 1967     2251.0            PG
# 1968     2251.0            PG
# 1969     2251.0            PG
#
# [1970 rows x 26 columns]

# %%
# Concatenate the DataFrames
concatenated_df = pd.concat([df_2000, df_2001], ignore_index=True)
pd.set_option('display.max_columns', None)  # Display all columns
concatenated_df
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 2     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 3     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 4     tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# ...         ...    ...                               ...
# 7230  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7231  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7232  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7233  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
# 7234  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg
#
#       belongs_to_collection      budget  \
# 0                       NaN         NaN
# 1                       NaN  50000000.0
# 2                       NaN  50000000.0
# 3                       NaN  50000000.0
# 4                       NaN  50000000.0
# ...                     ...         ...
# 7230                    NaN  50000000.0
# 7231                    NaN  50000000.0
# 7232                    NaN  50000000.0
# 7233                    NaN  50000000.0
# 7234                    NaN  50000000.0
#
#                                                  genres  \
# 0                                                   NaN
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4     [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# ...                                                 ...
# 7230  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7231  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7232  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7233  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 7234  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                               homepage        id original_language  \
# 0                                  NaN       NaN               NaN
# 1     https://www.tomandjerrymovie.com  587807.0                en
# 2     https://www.tomandjerrymovie.com  587807.0                en
# 3     https://www.tomandjerrymovie.com  587807.0                en
# 4     https://www.tomandjerrymovie.com  587807.0                en
# ...                                ...       ...               ...
# 7230  https://www.tomandjerrymovie.com  587807.0                en
# 7231  https://www.tomandjerrymovie.com  587807.0                en
# 7232  https://www.tomandjerrymovie.com  587807.0                en
# 7233  https://www.tomandjerrymovie.com  587807.0                en
# 7234  https://www.tomandjerrymovie.com  587807.0                en
#
#      original_title                                           overview  \
# 0               NaN                                                NaN
# 1       Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# 2       Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# 3       Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# 4       Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# ...             ...                                                ...
# 7230    Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# 7231    Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# 7232    Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# 7233    Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
# 7234    Tom & Jerry  Tom the cat and Jerry the mouse get kicked out...
#
#       popularity                       poster_path  \
# 0            NaN                               NaN
# 1         52.039  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# 2         52.039  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# 3         52.039  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# 4         52.039  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# ...          ...                               ...
# 7230      51.915  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# 7231      51.915  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# 7232      51.915  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# 7233      51.915  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
# 7234      51.915  /8XZI9QZ7Pm3fVkigWJPbrXCMzjq.jpg
#
#                                    production_companies  \
# 0                                                   NaN
# 1     [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# 2     [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# 3     [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# 4     [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# ...                                                 ...
# 7230  [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# 7231  [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# 7232  [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# 7233  [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
# 7234  [{'id': 25120, 'logo_path': '/lMj6nMJBOzfLEd2f...
#
#                                    production_countries release_date  \
# 0                                                   NaN          NaN
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# 2     [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# ...                                                 ...          ...
# 7230  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# 7231  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# 7232  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# 7233  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
# 7234  [{'iso_3166_1': 'US', 'name': 'United States o...   2021-02-10
#
#           revenue  runtime                                   spoken_languages  \
# 0             NaN      NaN                                                NaN
# 1     136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 2     136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 3     136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 4     136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# ...           ...      ...                                                ...
# 7230  136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7231  136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7232  136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7233  136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
# 7234  136536687.0    101.0  [{'english_name': 'English', 'iso_639_1': 'en'...
#
#         status                             tagline        title  video  \
# 0          NaN                                 NaN          NaN    NaN
# 1     Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# 2     Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# 3     Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# 4     Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# ...        ...                                 ...          ...    ...
# 7230  Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# 7231  Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# 7232  Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# 7233  Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
# 7234  Released  Best of enemies. Worst of friends.  Tom & Jerry    0.0
#
#       vote_average  vote_count certification
# 0              NaN         NaN           NaN
# 1            6.876      2243.0            PG
# 2            6.876      2243.0            PG
# 3            6.876      2243.0            PG
# 4            6.876      2243.0            PG
# ...            ...         ...           ...
# 7230         6.876      2251.0            PG
# 7231         6.876      2251.0            PG
# 7232         6.876      2251.0            PG
# 7233         6.876      2251.0            PG
# 7234         6.876      2251.0            PG
#
# [7235 rows x 26 columns]

# %% [markdown]
# ### How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# - Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.

# %%
# Filter out rows with both budget and revenue as 0
financial_df = concatenated_df[(concatenated_df['budget'] > 0) | (concatenated_df['revenue'] > 0)]

# Count them
movies_valid_info = len(financial_df)

# %%
movies_valid_info
# Out:
# 7233

# %% [markdown]
# ### How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
# Group the DataFrame by certification and count the number of movies in each category
certification_counts = concatenated_df['certification'].value_counts()

# Print the result
print("Number of movies in each certification category:")
print(certification_counts)
# Out:
# Number of movies in each certification category:
# PG    7233
# Name: certification, dtype: int64

# %% [markdown]
# ### What is the average revenue per certification category?

# %%
# DataFrame by certification and calculate the average revenue 
avg_rev_certification = concatenated_df.groupby('certification')['revenue'].mean()

avg_rev_certification
# Out:
# certification
# PG    136536687.0
# Name: revenue, dtype: float64

# %% [markdown]
# ### What is the average budget per certification category?

# %%
avg_budget_certification = concatenated_df.groupby('certification')['budget'].mean()

avg_budget_certification
# Out:
# certification
# PG    50000000.0
# Name: budget, dtype: float64
